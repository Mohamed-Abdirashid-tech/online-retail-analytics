# %% [markdown]
# # Data Loading

# %% [markdown]
# # PORTFOLIO PROJECT
#
# DATA ANALYSIS | DATA SCIENCE | BUSINESS INTELLIGENCE

# %% [markdown]
# # Online Retail Analytics
#
# ### Project Objective
#
# The objective of this notebook is to load the Online Retail II dataset, inspect its structure, verify data quality, and prepare it for the data cleaning phase.
#
# ---
#
# **Author:** MOHAMED ABDIRASHID MOHAMUD
#
# **Project:** Online Retail Analytics
#
# **Tools:** Python, Pandas, NumPy, JupyterLab
#
# **Dataset:** online_retail_II.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 20)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## Project Directory
#
# ```
# Online-Retail-Analytics/
# │
# ├── data/
# │   ├── raw/
# │   │   └── online_retail_II.csv
# │   └── processed/
# │
# ├── notebooks/
# │   └── 01_Data_Loading.ipynb
# │
# ├── reports/
# ├── src/
# └── README.md
# ```

# %%
from pathlib import Path

# %%
DATA_PATH = Path("../data/raw/online_retail_II.csv")

df = pd.read_csv(DATA_PATH)

print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#            InvoiceDate  Price  Customer ID         Country
# 0  2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2  2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3  2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4  2009-12-01 07:45:00   1.25      13085.0  United Kingdom
